# %% [markdown]
# ## string projects
#
# #### divisibility
#
# برنامه ای بنویسید که از کاربر دو عدد بگیره بررسی کنه به هم بخش پذیر هستند یا خیر

# %%
num_1 = int(input("Add number :"))
num_2 = int(input("Add number :"))

if num_2 % num_1 == 0 :
    print("divisibility ")

else :
    print("Not divisibility ")
# Out:
# divisibility

# %% [markdown]
# #### Store invoice
#
# برنامه ای که اطلاعات یک فاکتور رو دریافت  کند سپس جمع فاکتور ها رو محاسبه کند

# %%
food = 60
number_food = 4

print(f"Taha's order \n You had {number_food} dishes, \n Each dish cost {food} Tomans,\nYour total bill will be {food * number_food} Tomans")
# Out:
# Taha's order
#  You had 4 dishes,
#  Each dish cost 60 Tomans,
# Your total bill will be 240 Tomans

# %% [markdown]
# #### Print string
#
# برنامه ای که جمله
# hello i'm Here
# را چاپ کند و سپس
# hlo
# را چاپ کند

# %%
massage = "hello i'm here"

print(massage)
print(massage[:5:2])
# Out:
# hello i'm here
# hlo

# %% [markdown]
# ## Big Alpha

# %%
name = "taha"
name = "T" + name[1:]
print(name)
# Out:
# Taha

# %% [markdown]
# # new study
#
# امروز باید بتونی تمرین جادی رو انجام بدی
# کار دیگه هم که باید قبلشون انجام بدی اینه که یک فایل نوت بوک یا پایتون باید اماده کنی داخلش تمام متد های رشته به همراه توضیح و برنامه ای که تستشون کرده باشد داشته باشی
