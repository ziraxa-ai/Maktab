# %% [markdown]
# true => بودن
#
# False => نبودن
#
#
# and => (و)
#
# or  => (یا)
#
# not => (نه)
#
# < => کوچکتر
#
# > => بزرگتر
#
# >= => بزرگ تر مساوی
#
# <= => کوچک تر مساوی
#
# == => برابری
#
# != => نامساوی
#
# =  => مساوی
#
# in => داخل
